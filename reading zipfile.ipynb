# %%
#reading zipfile
import geopandas as gpd
zip_file = r'G:\Manjar\github\boundary\IndiaStateBound.zip'
zip_gdf = gpd.read_file(zip_file)
zip_gdf
# Out:
#                                          STATE  State_LGD    Shape_Leng  \
# 0                            ANDAMAN & NICOBAR         35  5.824763e+06
# 1                               ANDHRA PRADESH         28  5.334647e+06
# 2                            ARUNACHAL PRADESH         12  2.618522e+06
# 3                                        ASSAM         18  3.228020e+06
# 4                                        BIHAR         10  2.980745e+06
# 5                                   CHANDIGARH          4  6.211308e+04
# 6                                 CHHATTISGARH         22  3.321743e+06
# 7           DADRA & NAGAR HAVELI & DAMAN & DIU         38  3.215824e+05
# 8                                        DELHI          7  2.348592e+05
# 9          DISPUTED (MADHYA PRADESH & GUJARAT)          0  1.806306e+04
# 10       DISPUTED (MADHYA PRADESH & RAJASTHAN)          0  4.384445e+04
# 11               DISPUTED (RAJATHAN & GUJARAT)          0  6.995392e+04
# ...
