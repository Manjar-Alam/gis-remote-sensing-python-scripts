# %%
#Reading data (shapefiles, geojsons, geopackages)
#Reading a local shapefile
import geopandas as gpd

file = r'G:\Manjar\github\boundary\STATE_BOUNDARY.shp'

gdf = gpd.read_file(file)

gdf.plot()
# Out:
# <Axes: >
